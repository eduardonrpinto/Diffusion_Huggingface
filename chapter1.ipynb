# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardonrpinto/Diffusion_Huggingface/blob/main/chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/eduardonrpinto/Diffusion_Huggingface.git
# Out:
# Cloning into 'Diffusion_Huggingface'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.

# %%
# %cd Diffusion_Huggingface
# Out:
# /content/Diffusion_Huggingface/Diffusion_Huggingface

# %%
# !git remote -v
# Out:
# origin	https://github.com/eduardonrpinto/Diffusion_Huggingface.git (fetch)
# origin	https://github.com/eduardonrpinto/Diffusion_Huggingface.git (push)
