# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardonrpinto/Diffusion_Huggingface/blob/main/chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.ssh
# !ssh-keygen -t ed25519 -C "eduardo.n.r.pinto@gmail.com" -f ~/.ssh/id_ed25519 -N ""
# Out:
# Generating public/private ed25519 key pair.
# /root/.ssh/id_ed25519 already exists.
# Overwrite (y/n)? y
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:GB2VE4Qdjmd6hnQ8IBGi/LISIFHuriZ81WT3qyQXJqE eduardo.n.r.pinto@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |... . +oo==+     |
# | + . . o.*+      |
# |o +   ..+ B.     |
# |o. .  .*.B .     |
# |. o .E=.So+      |
# | o o . .oo..     |
# |o o .  . o  .    |
# |.= .    +  .     |
# |+ .      ..      |
# +----[SHA256]-----+

# %%
# !cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIPsbXLCXfiXWHL2MlZ73oD/bHSSLs1zyUlckkZVzrjx8 eduardo.n.r.pinto@gmail.com

# %%
# !ssh-keyscan github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-cb4a187
# # github.com:22 SSH-2.0-cb4a187
# # github.com:22 SSH-2.0-cb4a187
# # github.com:22 SSH-2.0-cb4a187
# # github.com:22 SSH-2.0-cb4a187

# %%
# !ssh -T git@github.com
# Out:
# Hi eduardonrpinto! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git clone git@github.com:eduardonrpinto/Diffusion_Huggingface.git
# Out:
# Cloning into 'Diffusion_Huggingface'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd Diffusion_Huggingface
# Out:
# /content/Diffusion_Huggingface

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ef14b72387d6.(none)')

# %%
# !git config --global user.name "eduardonrpinto"

# %%
# !git push
# Out:
# Everything up-to-date
